# %%
# 1. Creating a list 
marks = [85, 92, 78, 90, 88]
print("Original list: ", marks)

# 2. Access Elements
print("First element: ", marks[0])
print("Last element: ", marks[-1])

# 3. slicing 
print("Middle three: ", marks[1:4])

# 4. Modify elements
marks[2] = 80
print("After update: ", marks)

# 5. Append & insert
marks.append(95)
marks.insert(1, 89)
print("After append & insert: ", marks)

# Concatenation
combined = marks + extra
print("Concatenated:", combined)

# Repetition
double_list = marks * 2
print("Repeated:", double_list)
# Out:
# Original list:  [85, 92, 78, 90, 88]
# First element:  85
# Last element:  88
# Middle three:  [92, 78, 90]
# After update:  [85, 92, 80, 90, 88]
# After append & insert:  [85, 89, 92, 80, 90, 88, 95]
# Concatenated: [85, 89, 92, 80, 90, 88, 95, 70, 75]
# Repeated: [85, 89, 92, 80, 90, 88, 95, 85, 89, 92, 80, 90, 88, 95]

# %%
# 7 . Built - in - list methods
print("Length: ", len(marks))
print("Maximum: ", max(marks))
print("Minimum: ", min(marks))

sorted_marks = sorted(marks)
print("sorted(new list): ", sorted_marks)

marks.sort(reverse = True)
print("sorted decending(in-place): ", marks)

marks.reverse()
print("Reversed: ", marks)

popped = marks.pop()
print("Popped element: ", popped)
print("Sfter pop: ", marks)

marks.remove(89)
print("After remove 89: ", marks)

print("Count of 90: ", marks.count(90)
# Out:
#   Cell In[16], line 22
#     print("Count of 90: ", marks.count(90)
#                                           ^
# _IncompleteInputError: incomplete input
