# %%
import pandas as pd
# sample data
data = {
    'Department' : ['HR','IT','HR', 'Finance', 'IT'],
    'Employee': ['Amit', 'Riya','Rahul', 'Rahul', 'Priya', 'Anile', 'Neha', 'sneha'],
    'salary' : [5000, 60000, 55000, 53000, 65000, 62000, 70000]
}

# Create DataFrame
df = pd.DataFrame(data)
print("Original DataFrame: \n", df)

# 1. Group by Department and calculate mean salary
group_mean = df.groupby("Department")
print('\n Average salary by Department: n', group_mean)

# 2. Group by Department and calculate total salary

group_sum = df,groupby('Department')
["salary"].sum()
print("n\n Total salary by Department: \n", group_sum)

# Group by departmenty and get multiple aggreations

group _stats = df.groupby('Department')
['salary'],agg(['min', 'max', 'mean', 'count'])

print('\n Group_wise statistic : \n', gro)
